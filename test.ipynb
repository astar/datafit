# %%
import pyfits as pf
import numpy as np

# %%
hdulist  = pf.open('test.fits')

# %%
hdulist.info()
# Out:
# Filename: test.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     130   ()           uint8
# 1                BinTableHDU     19   1997R x 2C   [D, D]

# %%
hdu = hdulist[1]
data = hdu.data
x = data['WAVE']
y = data['FLUX']

# %%
plot(x,y )

# %%
z = [   2.32104891E-09, -3.35723162E-05,8.46922472E-02, 437.759705,-1078847.25,]
p = np.poly1d(z)

# %%
plot(x, y/f(x))

# %% [markdown]
# ## polyfit

# %%
z = np.polyfit(x, y, 5)
p = np.poly1d(z)

# %%
plot(x, y/f(x))
